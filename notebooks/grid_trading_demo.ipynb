# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from dateutil.relativedelta import relativedelta
import yfinance as yf
import seaborn as sns
sns.set(style='darkgrid')

import sys
sys.path.append('../src') 
from utils import (stock_trading_strategy,
                   stock_trading_strategy_backwards,
                   plot_trading_strategy,
                   download_stock_df,
                   user_function,
                   plot_candlestick,
                  )

# %%
user_function()
# Out:
# Enter the stock name:xbtf
# Enter the strategy start date, in YYYY-MM-DD format (default: 2022-10-18):2023-04-19
# Enter the strategy end date, in YYYY-MM-DD format (default: 2023-10-18):
# Would you like to customerize the strategy parameters? Enter Y for yes; otherwise would use default value
# [*********************100%***********************]  1 of 1 completed
# Strategy specifics:
#     stock name: XBTF
#     strategy start date: 2023-04-19, strategy end date: 2023-10-18
#     initial cash: 10000, each investment: 1000, buy_threshold: 0.05, sell_threshold: 0.05
#
#
# Final Profit: 617.2665725617553
# Underlying stock price change: -5.01%
# Max Profit ever: 617.2665725617553
# Max Loss ever: -66.25466712771231
# Number of Purchase & Sell actions: 18
# Minimal Cash Reserved:  7153.901109995759
#
#
# Transaction samples:
#          date  daily_price    action  num_shares_purchased  purchase_value
# 0  2023-04-19    29.129999  Purchase             34.328872          1000.0  \
# 2  2023-04-21    27.200001  Purchase             36.764705          1000.0
# 6  2023-04-27    29.580000      Sell              0.000000             0.0
# 8  2023-05-01    27.620001  Purchase             36.205647          1000.0
# 12 2023-05-05    29.454000      Sell              0.000000             0.0
#
#     num_shares_sold   sell_value  total_num_shares  total_stock_value
# 0          0.000000     0.000000         34.328872        1000.000000  \
# 2          0.000000     0.000000         71.093576        1933.745333
# 6         36.764705  1087.499967         34.328872        1015.448018
# 8          0.000000     0.000000         70.534519        1948.163462
# 12        36.205647  1066.401143         34.328872        1011.122599
#
#      total_cash
# 0   9000.000000
# 2   8000.000000
# 6   9087.499967
# 8   8087.499967
# 12  9153.901110
