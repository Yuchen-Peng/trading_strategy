# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from dateutil.relativedelta import relativedelta
import yfinance as yf
import seaborn as sns
sns.set(style='darkgrid')

import sys
sys.path.append('../src') 
from utils import (stock_trading_strategy,
                   stock_trading_strategy_backwards,
                   stock_trading_strategy_finer,
                   plot_trading_strategy,
                   plot_trading_strategy_finer,
                   download_stock_df,
                   download_stock_df_full,
                   user_function,
                   plot_candlestick,
                  )

# %%
# df_yinn = download_stock_df_full('yinn')
# result = stock_trading_strategy_finer(
#     df_yinn,
#     '2023-04-30',
#     end_date=datetime.today().strftime('%Y-%m-%d'),
#     initial_cash=10000,
#     investment=1000,
#     buy_threshold=0.05,
#     sell_threshold=0.1,
#     multiplier=1)
# print((result.iloc[-1]['total_stock_value'] + result.iloc[-1]['total_cash'])-10000)

# result = stock_trading_strategy_finer(
#     df_yinn,
#     '2023-04-30',
#     end_date=datetime.today().strftime('%Y-%m-%d'),
#     initial_cash=10000,
#     investment=2000,
#     buy_threshold=0.05,
#     sell_threshold=0.1,
#     multiplier=1)
# print((result.iloc[-1]['total_stock_value'] + result.iloc[-1]['total_cash'])-10000)

# result = stock_trading_strategy_finer(
#     df_yinn,
#     '2023-04-30',
#     end_date=datetime.today().strftime('%Y-%m-%d'),
#     initial_cash=10000,
#     investment=2000,
#     buy_threshold=0.06,
#     sell_threshold=0.1,
#     multiplier=1)
# print((result.iloc[-1]['total_stock_value'] + result.iloc[-1]['total_cash'])-10000)

# result = stock_trading_strategy_finer(
#     df_yinn,
#     '2023-04-30',
#     end_date=datetime.today().strftime('%Y-%m-%d'),
#     initial_cash=10000,
#     investment=1000,
#     buy_threshold=0.06,
#     sell_threshold=0.1,
#     multiplier=1)
# print((result.iloc[-1]['total_stock_value'] + result.iloc[-1]['total_cash'])-10000)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1360.7547955964
# 2204.790435546118
# 1479.0438049024542
# 739.521902451228

# %%
result = stock_trading_strategy_finer(
    df_yinn,
    '2023-04-30',
    end_date=datetime.today().strftime('%Y-%m-%d'),
    initial_cash=10000,
    investment=2000,
    buy_threshold=0.05,
    sell_threshold=0.1,
    multiplier=1)
result[result['action']!='Pass']
# Out:
#           date       open      close       high        low    action
# 0   2023-05-01  40.509998  40.380001  41.459999  40.320000  Purchase  \
# 1   2023-05-02  39.110001  37.970001  39.180000  37.220001  Purchase
# 4   2023-05-05  41.330002  42.169998  42.369999  40.779999      Sell
# 9   2023-05-12  39.650002  38.279999  39.650002  37.919998  Purchase
# 10  2023-05-15  41.240002  43.180000  43.369999  40.709999      Sell
# 13  2023-05-18  40.529999  39.009998  40.650002  38.299999  Purchase
# 16  2023-05-23  37.900002  36.529999  38.139999  36.410000  Purchase
# 17  2023-05-24  35.299999  34.299999  35.490002  34.080002  Purchase
# 18  2023-05-25  33.369999  32.119999  33.410000  31.950001  Purchase
# 20  2023-05-30  32.119999  30.760000  32.330002  30.250000  Purchase
# 21  2023-05-31  30.059999  30.469999  30.469999  28.850000  Purchase
# 22  2023-06-01  30.450001  32.770000  33.130001  30.400000      Sell
# 23  2023-06-02  35.340000  35.639999  36.330002  35.299999      Sell
# ...

# %%
user_function()
# Out:
# Enter the stock name:yinn
# Enter the strategy start date, in YYYY-MM-DD format (default: 2022-10-20):2023-04-30
# Enter the strategy end date, in YYYY-MM-DD format (default: 2023-10-20):
# Would you like to customerize the strategy parameters? Enter Y for yes; otherwise would use default valuey
# Enter the initial cash (default: 10000):
# Enter the investment amount for each purchase (default: 1000):
# If the stock price drops X percent, make a purchase. Enter X as an integer (default: 5):
# If the stock price rises X percent, make a sell. Enter X as an integer (default: 5):10
# Would you like to use the finer strategy? Enter Y for yes, otherwise use default
# [*********************100%***********************]  1 of 1 completed
# Strategy specifics:
#     stock name: YINN
#     strategy start date: 2023-04-30, strategy end date: 2023-10-20
#     initial cash: 10000.0, each investment: 1000.0, buy_threshold: 0.05, sell_threshold: 0.1
#     strategy used: default
#
#
# ...

# %%
user_function()
# Out:
# Enter the stock name:yinn
# Enter the strategy start date, in YYYY-MM-DD format (default: 2022-10-20):2023-04-30
# Enter the strategy end date, in YYYY-MM-DD format (default: 2023-10-20):
# Would you like to customerize the strategy parameters? Enter Y for yes; otherwise would use default valuey
# Enter the initial cash (default: 10000):
# Enter the investment amount for each purchase (default: 1000):
# If the stock price drops X percent, make a purchase. Enter X as an integer (default: 5):
# If the stock price rises X percent, make a sell. Enter X as an integer (default: 5):10
# Would you like to use the finer strategy? Enter Y for yes, otherwise use defaulty
# [*********************100%***********************]  1 of 1 completed
# Strategy specifics:
#     stock name: YINN
#     strategy start date: 2023-04-30, strategy end date: 2023-10-20
#     initial cash: 10000.0, each investment: 1000.0, buy_threshold: 0.05, sell_threshold: 0.1
#     strategy used: finer
#
#
# ...

# %%
user_function()
# Out:
# Enter the stock name:xbtf
# Enter the strategy start date, in YYYY-MM-DD format (default: 2022-10-20):2023-04-30
# Enter the strategy end date, in YYYY-MM-DD format (default: 2023-10-20):
# Would you like to customerize the strategy parameters? Enter Y for yes; otherwise would use default valuey
# Enter the initial cash (default: 10000):
# Enter the investment amount for each purchase (default: 1000):3000
# If the stock price drops X percent, make a purchase. Enter X as an integer (default: 5):
# If the stock price rises X percent, make a sell. Enter X as an integer (default: 5):
# [*********************100%***********************]  1 of 1 completed
# Strategy specifics:
#     stock name: XBTF
#     strategy start date: 2023-04-30, strategy end date: 2023-10-20
#     initial cash: 10000.0, each investment: 3000.0, buy_threshold: 0.05, sell_threshold: 0.05
#
#
# Final Profit: 1486.3142124068327
# Underlying stock price change: 1.23%
# Max Profit ever: 1486.3142124068327
# ...
