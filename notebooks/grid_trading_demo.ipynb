# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from dateutil.relativedelta import relativedelta
import yfinance as yf
import seaborn as sns
sns.set(style='darkgrid')

import sys
sys.path.append('../src') 
from utils import (stock_trading_strategy,
                   stock_trading_strategy_backwards,
                   stock_trading_strategy_finer,
                   plot_trading_strategy,
                   plot_trading_strategy_finer,
                   download_stock_df,
                   download_stock_df_full,
                   user_function,
                   plot_candlestick,
                  )

# %%
# df_yinn = download_stock_df_full('yinn')
# result = stock_trading_strategy_finer(
#     df_yinn,
#     '2023-04-30',
#     end_date=datetime.today().strftime('%Y-%m-%d'),
#     initial_cash=10000,
#     investment=1000,
#     buy_threshold=0.05,
#     sell_threshold=0.1,
#     multiplier=1)
# print((result.iloc[-1]['total_stock_value'] + result.iloc[-1]['total_cash'])-10000)

# result = stock_trading_strategy_finer(
#     df_yinn,
#     '2023-04-30',
#     end_date=datetime.today().strftime('%Y-%m-%d'),
#     initial_cash=10000,
#     investment=2000,
#     buy_threshold=0.05,
#     sell_threshold=0.1,
#     multiplier=1)
# print((result.iloc[-1]['total_stock_value'] + result.iloc[-1]['total_cash'])-10000)

# result = stock_trading_strategy_finer(
#     df_yinn,
#     '2023-04-30',
#     end_date=datetime.today().strftime('%Y-%m-%d'),
#     initial_cash=10000,
#     investment=2000,
#     buy_threshold=0.06,
#     sell_threshold=0.1,
#     multiplier=1)
# print((result.iloc[-1]['total_stock_value'] + result.iloc[-1]['total_cash'])-10000)

# result = stock_trading_strategy_finer(
#     df_yinn,
#     '2023-04-30',
#     end_date=datetime.today().strftime('%Y-%m-%d'),
#     initial_cash=10000,
#     investment=1000,
#     buy_threshold=0.06,
#     sell_threshold=0.1,
#     multiplier=1)
# print((result.iloc[-1]['total_stock_value'] + result.iloc[-1]['total_cash'])-10000)

# %%
user_function()
# Out:
# Enter the stock name: yinn
# Enter the strategy start date, in YYYY-MM-DD format (default: 2022-10-27): 2023-04-30
# Enter the strategy end date, in YYYY-MM-DD format (default: 2023-10-27):
# Would you like to customerize the strategy parameters? Enter Y for yes; otherwise would use default value y
# Enter the initial cash (default: 10000):
# Enter the investment amount for each purchase (default: 1000):
# If the stock price drops X percent, make a purchase. Enter X as an integer (default: 5):
# If the stock price rises X percent, make a sell. Enter X as an integer (default: 5): 10
# Would you like to use the finer strategy? Enter Y for yes, otherwise use default y
# [*********************100%%**********************]  1 of 1 completed
# Strategy specifics:
#     stock name: YINN
#     strategy start date: 2023-04-30, strategy end date: 2023-10-27
#     initial cash: 10000.0, each investment: 1000.0, buy_threshold: 0.05, sell_threshold: 0.1
#     strategy used: finer
#
#
# Final Profit: 1428.447091162272
# Underlying stock price change: -37.35%
# Max Profit ever: 2217.8377978225035
# Max Loss ever: -491.1901986725279
# Number of Purchase & Sell actions: 51
# Minimal Cash Reserved:  3238.617782091438
#
#
# Transaction samples:
#          date       open      close       high        low    action  \
# 0  2023-05-01  40.509998  40.380001  41.459999  40.320000  Purchase
# 1  2023-05-02  39.110001  37.970001  39.180000  37.220001  Purchase
# 4  2023-05-05  41.330002  42.169998  42.369999  40.779999      Sell
# 9  2023-05-12  39.650002  38.279999  39.650002  37.919998  Purchase
# 10 2023-05-15  41.240002  43.180000  43.369999  40.709999      Sell
#
#     action_price  buy_price_planned  sell_price_planned  num_shares_purchased  \
# 0      40.380001          40.380001                 NaN             24.764734
# 1      37.970001          38.361001           44.418001             26.336581
# 4      42.169998          36.071501           41.767001              0.000000
# 9      38.279999          38.361001           44.418001             26.123303
# 10     43.180000          36.365999           42.107999              0.000000
#
#     purchase_value  num_shares_sold   sell_value  total_num_shares  \
# 0           1000.0         0.000000     0.000000         24.764734
# 1           1000.0         0.000000     0.000000         51.101315
# 4              0.0        26.336581  1110.613558         24.764734
# 9           1000.0         0.000000     0.000000         50.888037
# 10             0.0        26.123303  1128.004224         24.764734
#
#     total_stock_value   total_cash
# 0         1000.000000  9000.000000
# 1         1940.316994  8000.000000
# 4         1044.328803  9110.613558
# 9         1947.994001  8110.613558
# 10        1069.341237  9238.617782

# %%
user_function()
# Out:
# Enter the stock name: yinn
# Enter the strategy start date, in YYYY-MM-DD format (default: 2022-10-27): 2023-04-30
# Enter the strategy end date, in YYYY-MM-DD format (default: 2023-10-27):
# Would you like to customerize the strategy parameters? Enter Y for yes; otherwise would use default value y
# Enter the initial cash (default: 10000):
# Enter the investment amount for each purchase (default: 1000): 2000
# If the stock price drops X percent, make a purchase. Enter X as an integer (default: 5):
# If the stock price rises X percent, make a sell. Enter X as an integer (default: 5): 10
# Would you like to use the finer strategy? Enter Y for yes, otherwise use default y
# [*********************100%%**********************]  1 of 1 completed
# Strategy specifics:
#     stock name: YINN
#     strategy start date: 2023-04-30, strategy end date: 2023-10-27
#     initial cash: 10000.0, each investment: 2000.0, buy_threshold: 0.05, sell_threshold: 0.1
#     strategy used: finer
#
#
# Final Profit: 2184.824384899257
# Underlying stock price change: -37.35%
# Max Profit ever: 3918.9564399983283
# Max Loss ever: -1079.5578910349832
# Number of Purchase & Sell actions: 51
# Minimal Cash Reserved:  0.0
#
#
# Transaction samples:
#          date       open      close       high        low    action  \
# 0  2023-05-01  40.509998  40.380001  41.459999  40.320000  Purchase
# 1  2023-05-02  39.110001  37.970001  39.180000  37.220001  Purchase
# 4  2023-05-05  41.330002  42.169998  42.369999  40.779999      Sell
# 9  2023-05-12  39.650002  38.279999  39.650002  37.919998  Purchase
# 10 2023-05-15  41.240002  43.180000  43.369999  40.709999      Sell
#
#     action_price  buy_price_planned  sell_price_planned  num_shares_purchased  \
# 0      40.380001          40.380001                 NaN             49.529469
# 1      37.970001          38.361001           44.418001             52.673161
# 4      42.169998          36.071501           41.767001              0.000000
# 9      38.279999          38.361001           44.418001             52.246606
# 10     43.180000          36.365999           42.107999              0.000000
#
#     purchase_value  num_shares_sold   sell_value  total_num_shares  \
# 0           2000.0         0.000000     0.000000         49.529469
# 1           2000.0         0.000000     0.000000        102.202630
# 4              0.0        52.673161  2221.227117         49.529469
# 9           2000.0         0.000000     0.000000        101.776074
# 10             0.0        52.246606  2256.008447         49.529469
#
#     total_stock_value   total_cash
# 0         2000.000000  8000.000000
# 1         3880.633988  6000.000000
# 4         2088.657605  8221.227117
# 9         3895.988002  6221.227117
# 10        2138.682475  8477.235564

# %%
user_function()
# Out:
# Enter the stock name: xbtf
# Enter the strategy start date, in YYYY-MM-DD format (default: 2022-10-21): 2023-04-30
# Enter the strategy end date, in YYYY-MM-DD format (default: 2023-10-21):
# Would you like to customerize the strategy parameters? Enter Y for yes; otherwise would use default value y
# Enter the initial cash (default: 10000):
# Enter the investment amount for each purchase (default: 1000): 3000
# If the stock price drops X percent, make a purchase. Enter X as an integer (default: 5):
# If the stock price rises X percent, make a sell. Enter X as an integer (default: 5):
# Would you like to use the finer strategy? Enter Y for yes, otherwise use default y
# [*********************100%%**********************]  1 of 1 completed
# Strategy specifics:
#     stock name: XBTF
#     strategy start date: 2023-04-30, strategy end date: 2023-10-21
#     initial cash: 10000.0, each investment: 3000.0, buy_threshold: 0.05, sell_threshold: 0.05
#     strategy used: finer
#
#
# Final Profit: 2059.333888547344
# Underlying stock price change: 3.98%
# Max Profit ever: 2059.333888547344
# Max Loss ever: 0.0
# Number of Purchase & Sell actions: 20
# Minimal Cash Reserved:  4199.203429912708
#
#
# Transaction samples:
#          date       open      close       high        low    action  \
# 0  2023-05-01  28.469999  27.620001  28.469999  27.620001  Purchase
# 4  2023-05-05  28.874001  29.454000  29.530001  28.874001      Sell
# 5  2023-05-08  27.760000  27.129999  27.768000  27.129999  Purchase
# 9  2023-05-12  26.200001  26.250000  26.280001  25.670000  Purchase
# 10 2023-05-15  27.209999  27.246000  27.340000  27.110001      Sell
#
#     action_price  buy_price_planned  sell_price_planned  num_shares_purchased  \
# 0      27.620001          27.620001                 NaN            108.616941
# 4      29.454000          26.239001           29.001001              0.000000
# 5      27.129999          27.129999                 NaN            110.578699
# 9      25.773499          25.773499           28.486499            116.398630
# 10     27.246000          24.484824           27.062174              0.000000
#
#     purchase_value  num_shares_sold   sell_value  total_num_shares  \
# 0           3000.0         0.000000     0.000000        108.616941
# 4              0.0       108.616941  3199.203430          0.000000
# 5           3000.0         0.000000     0.000000        110.578699
# 9           3000.0         0.000000     0.000000        226.977329
# 10             0.0       116.398630  3171.397109        110.578699
#
#     total_stock_value    total_cash
# 0         3000.000000   7000.000000
# 4            0.000000  10199.203430
# 5         3000.000000   7199.203430
# 9         5958.154878   4199.203430
# 10        3012.827254   7370.600539

# %%
user_function()
# Out:
# Enter the stock name: xle
# Enter the strategy start date, in YYYY-MM-DD format (default: 2022-10-29): 2023-03-09
# Enter the strategy end date, in YYYY-MM-DD format (default: 2023-10-29):
# Would you like to customerize the strategy parameters? Enter Y for yes; otherwise would use default value y
# Enter the initial cash (default: 10000):
# Enter the investment amount for each purchase (default: 1000): 2000
# If the stock price drops X percent, make a purchase. Enter X as an integer (default: 5):
# If the stock price rises X percent, make a sell. Enter X as an integer (default: 5): 10
# Would you like to use the finer strategy? Enter Y for yes, otherwise use default y
# [*********************100%%**********************]  1 of 1 completed
# Strategy specifics:
#     stock name: XLE
#     strategy start date: 2023-03-09, strategy end date: 2023-10-29
#     initial cash: 10000.0, each investment: 2000.0, buy_threshold: 0.05, sell_threshold: 0.1
#     strategy used: finer
#
#
# Final Profit: 892.3183639715626
# Underlying stock price change: 1.11%
# Max Profit ever: 892.3183639715626
# Max Loss ever: -205.6968700157122
# Number of Purchase & Sell actions: 8
# Minimal Cash Reserved:  4000.0
#
#
# Transaction samples:
#          date       open      close       high        low    action  \
# 0  2023-03-09  85.389999  83.699997  86.589996  83.680000  Purchase
# 2  2023-03-13  80.519997  80.949997  82.400002  79.110001  Purchase
# 5  2023-03-16  75.660004  78.199997  78.400002  75.360001  Purchase
# 17 2023-04-03  86.320000  86.580002  87.139999  85.870003      Sell
# 25 2023-04-14  87.190002  87.230003  87.739998  86.720001      Sell
#
#     action_price  buy_price_planned  sell_price_planned  num_shares_purchased  \
# 0      83.699997          83.699997                 NaN             23.894863
# 2      79.514997          79.514997           92.069997             25.152488
# 5      75.539247          75.539247           87.466497             26.476303
# 17     86.580002          71.762285           83.093172              0.000000
# 25     87.466497          75.539247           87.466497              0.000000
#
#     purchase_value  num_shares_sold   sell_value  total_num_shares  \
# 0           2000.0         0.000000     0.000000         23.894863
# 2           2000.0         0.000000     0.000000         49.047351
# 5           2000.0         0.000000     0.000000         75.523654
# 17             0.0        26.476303  2292.318364         49.047351
# 25             0.0        25.152488  2200.000000         23.894863
#
#     total_stock_value   total_cash
# 0         2000.000000  8000.000000
# 2         3970.382942  6000.000000
# 5         5905.949541  4000.000000
# 17        4246.519769  6292.318364
# 25        2084.349021  8492.318364

# %%
user_function()
# Out:
# Enter the stock name: vxx
# Enter the strategy start date, in YYYY-MM-DD format (default: 2022-10-29): 2023-06-12
# Enter the strategy end date, in YYYY-MM-DD format (default: 2023-10-29):
# Would you like to customerize the strategy parameters? Enter Y for yes; otherwise would use default value y
# Enter the initial cash (default: 10000):
# Enter the investment amount for each purchase (default: 1000):
# If the stock price drops X percent, make a purchase. Enter X as an integer (default: 5):
# If the stock price rises X percent, make a sell. Enter X as an integer (default: 5):
# Would you like to use the finer strategy? Enter Y for yes, otherwise use default y
# [*********************100%%**********************]  1 of 1 completed
# Strategy specifics:
#     stock name: VXX
#     strategy start date: 2023-06-12, strategy end date: 2023-10-29
#     initial cash: 10000.0, each investment: 1000.0, buy_threshold: 0.05, sell_threshold: 0.05
#     strategy used: finer
#
#
# Final Profit: 1176.1741543657117
# Underlying stock price change: -4.95%
# Max Profit ever: 1176.1741543657117
# Max Loss ever: -522.367855209035
# Number of Purchase & Sell actions: 37
# Minimal Cash Reserved:  4520.268868970326
#
#
# Transaction samples:
#          date       open      close       high        low    action  \
# 0  2023-06-12  28.469999  28.490000  28.900000  28.299999  Purchase
# 6  2023-06-21  27.040001  26.790001  27.275000  26.684999  Purchase
# 10 2023-06-27  26.200001  25.770000  26.209999  25.235001  Purchase
# 16 2023-07-06  26.260000  26.510000  28.900000  26.260000      Sell
# 19 2023-07-11  25.209999  25.469999  25.900999  25.059999  Purchase
#
#     action_price  buy_price_planned  sell_price_planned  num_shares_purchased  \
# 0      28.490000          28.490000                 NaN             35.100035
# 6      26.790001          27.065500           29.914500             37.327360
# 10     25.450501          25.450501           28.129501             39.291958
# 16     26.723026          24.177976           26.723026              0.000000
# 19     25.450501          25.450501           28.129501             39.291958
#
#     purchase_value  num_shares_sold  sell_value  total_num_shares  \
# 0           1000.0         0.000000         0.0         35.100035
# 6           1000.0         0.000000         0.0         72.427395
# 10          1000.0         0.000000         0.0        111.719353
# 16             0.0        39.291958      1050.0         72.427395
# 19          1000.0         0.000000         0.0        111.719353
#
#     total_stock_value  total_cash
# 0         1000.000000      9000.0
# 6         1940.329980      8000.0
# 10        2879.007768      7000.0
# 16        1920.050260      8050.0
# 19        2845.491835      7050.0
