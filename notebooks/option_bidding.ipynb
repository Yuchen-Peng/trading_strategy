# %%
# !pip install googlefinance
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googlefinance: filename=googlefinance-0.7-py3-none-any.whl size=2563 sha256=1919bf1788e1ebd38b42fc8ab45ca35423b725cdb477417506e2b0542b4d40d2
#   Stored in directory: /Users/yuchen/Library/Caches/pip/wheels/95/6c/b2/648911716579934b2b1964cd6a10992bd6b6d3ca444d29a812
# Successfully built googlefinance
# ...

# %%
# !pip install yfinance --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.41
#     Uninstalling yfinance-0.2.41:
#       Successfully uninstalled yfinance-0.2.41
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import yfinance as yf

import sys
sys.path.append('../src') 
from stock_strategy import stock_strategy

# %%
s_ticker = 'YINN'
ticker = yf.Ticker(s_ticker)
data = ticker.options
print(data)
# Out:
# ('2024-10-11', '2024-10-18', '2024-10-25', '2024-11-01', '2024-11-08', '2024-11-15', '2024-11-22', '2024-12-20', '2025-01-17', '2025-04-17', '2026-01-16', '2027-01-15')

# %%
df_puts = ticker.option_chain(data[0]).puts
df_puts.head(10)
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice  bid  \
# 0  YINN241011P00015000 2024-09-12 15:14:29+00:00    15.0       0.08  0.0
# 1  YINN241011P00016000 2024-09-17 13:36:26+00:00    16.0       0.08  0.0
# 2  YINN241011P00017000 2024-10-01 17:41:05+00:00    17.0       0.01  0.0
# 3  YINN241011P00017500 2024-09-24 13:30:11+00:00    17.5       0.05  0.0
# 4  YINN241011P00018000 2024-10-04 17:54:45+00:00    18.0       0.04  0.0
# 5  YINN241011P00018500 2024-10-07 13:40:03+00:00    18.5       0.05  0.0
# 6  YINN241011P00019000 2024-10-07 13:40:02+00:00    19.0       0.05  0.0
# 7  YINN241011P00019500 2024-10-07 13:30:00+00:00    19.5       0.05  0.0
# 8  YINN241011P00020000 2024-10-07 14:45:34+00:00    20.0       0.03  0.0
# 9  YINN241011P00020500 2024-10-07 13:40:04+00:00    20.5       0.05  0.0
#
#     ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0  0.05    0.00       0.000000     NaN            10           4.468754
# ...

# %%
option_symbol = "YINN241011P00015000"

# Get real-time option data
option_data = yf.Ticker(option_symbol).info

# Extract bid and ask quantities
bid_quantity = option_data['bidSize']
ask_quantity = option_data['askSize']

# Print the results
print("Bid Quantity:", bid_quantity)
print("Ask Quantity:", ask_quantity)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 7
#       4 option_data = yf.Ticker(option_symbol).info
#       6 # Extract bid and ask quantities
# ----> 7 bid_quantity = option_data['bidSize']
#       8 ask_quantity = option_data['askSize']
#      10 # Print the results
#
# KeyError: 'bidSize'

# %%
option_data
# Out:
# {'maxAge': 86400,
#  'priceHint': 4,
#  'previousClose': 0.08,
#  'dayLow': 0.08,
#  'dayHigh': 0.08,
#  'regularMarketPreviousClose': 0.08,
#  'regularMarketDayLow': 0.08,
#  'regularMarketDayHigh': 0.08,
#  'ask': 0.05,
#  'expireDate': 1728604800,
#  'strikePrice': 15.0,
#  'openInterest': 10,
#  'fiftyTwoWeekLow': 0.08,
#  'fiftyTwoWeekHigh': 0.08,
#  'currency': 'USD',
#  'exchange': 'OPR',
#  'quoteType': 'OPTION',
#  'symbol': 'YINN241011P00015000',
#  'underlyingSymbol': 'YINN',
#  'shortName': 'YINN Oct 2024 15.000 put',
#  'firstTradeDateEpochUtc': 1726459200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '01009744-edb9-3941-825e-13e969219ad2',
#  'gmtOffSetMilliseconds': -14400000,
#  'trailingPegRatio': None}

# %%
import yfinance as yf

# Option symbol (replace with your desired symbol)
option_symbol = "YINN241011P00015000"

# Get real-time option quotes
option_quotes = yf.Ticker(option_symbol).get_quotes()

# Extract bid and ask quantities
bid_quantity = option_quotes['bidSize'][0]
ask_quantity = option_quotes['askSize'][0]

# Print the results
print("Bid Quantity:", bid_quantity)
print("Ask Quantity:", ask_quantity)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 7
#       4 option_symbol = "YINN241011P00015000"
#       6 # Get real-time option quotes
# ----> 7 option_quotes = yf.Ticker(option_symbol).get_quotes()
#       9 # Extract bid and ask quantities
#      10 bid_quantity = option_quotes['bidSize'][0]
#
# AttributeError: 'Ticker' object has no attribute 'get_quotes'
