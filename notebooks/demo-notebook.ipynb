# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from dateutil.relativedelta import relativedelta
import yfinance as yf
import seaborn as sns
sns.set(style='darkgrid')

import sys
sys.path.append('../src') 
from utils import (stock_trading_strategy,
                   stock_trading_strategy_backwards,
                   plot_trading_strategy,
                   download_stock_df,
                   user_function,
                   plot_candlestick,
                  )

# %%
user_function()
# Out:
# Enter the stock name:yinn
# Enter the strategy start date, in YYYY-MM-DD format (default: 2022-09-22):
# Enter the strategy end date, in YYYY-MM-DD format (default: 2023-09-22):
# Would you like to customerize the strategy parameters? Enter Y for yes; otherwise would use default valuey
# Enter the initial cash (default: 10000):
# Enter the investment amount for each purchase (default: 1000):
# If the stock price drops X percent, make a purchase. Enter X as an integer (default: 5):
# If the stock price rises X percent, make a sell. Enter X as an integer (default: 5):10
# [*********************100%***********************]  1 of 1 completed
# Strategy specifics:
#     stock name: YINN
#     strategy start date: 2022-09-22, strategy end date: 2023-09-22
#     initial cash: 10000.0, each investment: 1000.0, buy_threshold: 0.05, sell_threshold: 0.1
#
#
# Final Profit: 3096.8343288041524
# Underlying stock price change: -39.54%
# Max Profit ever: 4332.689026652535
# Max Loss ever: -2719.202841907587
# Number of Purchase & Sell actions: 67
# Minimal Cash Reserved:  1293.2699757883775
#
#
# Transaction samples:
#          date  daily_price    action  num_shares_purchased  purchase_value
# 0  2022-09-22    46.660000  Purchase             21.431633          1000.0  \
# 3  2022-09-27    44.049999  Purchase             22.701476          1000.0
# 5  2022-09-29    41.320000  Purchase             24.201355          1000.0
# 8  2022-10-04    46.259998      Sell              0.000000             0.0
# 12 2022-10-10    38.950001  Purchase             25.673940          1000.0
#
#     num_shares_sold   sell_value  total_num_shares  total_stock_value
# 0          0.000000     0.000000         21.431633        1000.000000  \
# 3          0.000000     0.000000         44.133109        1944.063424
# 5          0.000000     0.000000         68.334465        2823.580057
# 8         24.201355  1119.554663         44.133109        2041.597555
# 12         0.000000     0.000000         69.807050        2718.984635
#
#      total_cash
# 0   9000.000000
# 3   8000.000000
# 5   7000.000000
# 8   8119.554663
# 12  7119.554663
